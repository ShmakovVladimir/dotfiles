# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Наш эксперимент

# %%
data = pd.read_csv('our.csv')
data.N /= np.max(data.N)
data.head()
# Out:
#          E         N
# 0  1065.75  0.000596
# 1  1079.18  0.000652
# 2  1092.61  0.000714
# 3  1106.04  0.000776
# 4  1119.47  0.000865

# %%
plt.figure(figsize=(12, 5), dpi = 200)
plt.scatter(data.E, data.N)
plt.xlabel(r"Энергия кванта $h \nu$ [мЭв]", fontsize = 14)
plt.ylabel(r"фотоответ [отн. ед.]", fontsize = 14)
# Out:
# Text(0, 0.5, 'фотоответ [отн. ед.]')
